# %%
breakpoint()

# %%
# %run precompute_lengths.py \
    experiment=lba_S \
    debug=default \
    ++data.dataset.split_identity_threshold=identity_30 \
    ++data.length_cache_dir=lengths/lba_identity_30_debug \
    ++data.max_total_atoms=25000
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\Documents\CBIO\ADiT\scripts\precompute_lengths.py:19
#       1 """Precompute the length (L = token count) cache used by DynamicBatchSampler.
#       2
#       3 Run this once (e.g. in an interactive `srun` session or a small 1-CPU job)
#    (...)
#      16 `cfg.data.length_cache_dir`.
#      17 """
#      18 import rootutils
# ---> 19 import hydra
#      20 from omegaconf import DictConfig
#      22 rootutils.setup_root(__file__, indicator=".project-root", pythonpath=True)
#
# File c:\miniconda\envs\cbio\lib\site-packages\hydra\__init__.py:5
#       1 # Copyright (c) Facebook, Inc. and its affiliates. All Rights Reserved
#       2
#       3 # Source of truth for Hydra's version
#       4 __version__ = "1.3.4"
# ----> 5 from hydra import utils
#       6 from hydra.errors import MissingConfigException
# ...

# %%
# %run ./scripts/precompute_lengths.py \
    experiment=skempi_S \
    debug=default \
    ++data.dataset.test_split=split_0 \
    ++data.length_cache_dir=lengths/skempi0_debug \
    ++data.max_total_atoms=25000
# Out:
# [2026-07-27 18:14:39,566][hydra.core.utils][DEBUG] - Setting JobRuntime:name=precompute_lengths
# Training set size: 4163
# Val set size: 4163
# Test set size: 2531
# Cached lengths under lengths/skempi0_debug

# %%
# %run ./scripts/precompute_lengths.py \
    experiment=new_denoise_S_pdb_fixed_0_5 \
    debug=default \
    ++data.length_cache_dir=lengths/pdb \
    ++data.max_total_atoms=25000
# Out:
# [2026-07-27 18:32:51,056][matplotlib][DEBUG] - matplotlib data path: /cluster/CBIO/home/snieradzikkozic/miniconda3/envs/adit/lib/python3.10/site-packages/matplotlib/mpl-data
# [2026-07-27 18:32:51,067][matplotlib][DEBUG] - CONFIGDIR=/cluster/CBIO/home/snieradzikkozic/.config/matplotlib
# [2026-07-27 18:32:51,313][matplotlib][DEBUG] - interactive is False
# [2026-07-27 18:32:51,317][matplotlib][DEBUG] - platform is linux
# [2026-07-27 18:32:51,377][matplotlib][DEBUG] - CACHEDIR=/cluster/CBIO/home/snieradzikkozic/.cache/matplotlib
# [2026-07-27 18:32:51,382][matplotlib.font_manager][DEBUG] - Using fontManager instance from /cluster/CBIO/home/snieradzikkozic/.cache/matplotlib/fontlist-v390.json
# [2026-07-27 18:32:56,291][numexpr.utils][INFO] - Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# [2026-07-27 18:32:56,295][numexpr.utils][INFO] - NumExpr defaulting to 16 threads.
# Training set size: 133959
# Val set size: 7050

# %%
# %run ./adit/train.py \
    experiment=new_denoise_S_pdb_fixed_0_5 \
    debug=default \
    ++data.max_pair_budget=250000 \
    ++data.max_total_atoms=15000
# Out:
# [2026-07-27 19:07:26,432][hydra.core.utils][DEBUG] - Setting JobRuntime:name=train
# [2026-07-27 19:07:35,862][adit.utils.utils][INFO] - [rank: 0] Printing config tree with Rich! <cfg.extras.print_config=True>
# CONFIG
# ├── data
# │   └── _target_: adit.data.protein_datamodule.ProteinDataModule
# │       dataset:
# │         _target_: adit.data.components.dataset.AditPDBDataset
# │         path_to_dataset: dataset/adit_pretrain_data
# │         metadata_filter:
# │           _target_: adit.data.components.metadata_filter.AditMetadataFilter
# │           min_len: 40
# │         transform:
# │           _target_: adit.data.components.feature_transform.AditDataFeatureTransform
# │           unit: nm
# │           truncate_length: 250
# │           strip_missing_residues: true
# │           recenter_and_scale: true
# │           eps: 1.0e-08
# │           pretrain: true
# │       batch_size: 24
# │       generator_seed: 42
# │       train_val_split:
# │       - 0.95
# │       - 0.05
# ...
